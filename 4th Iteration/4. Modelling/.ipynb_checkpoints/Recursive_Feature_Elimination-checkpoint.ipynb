# %%
from sklearn.feature_selection import RFE

# %%
# Recursive Feature Elimination
from sklearn import datasets
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
# load the iris datasets
dataset = datasets.load_iris()
# create a base classifier used to evaluate a subset of attributes
model = LogisticRegression()
# create the RFE model and select 3 attributes
rfe = RFE(model, 3)
rfe = rfe.fit(dataset.data, dataset.target)
# summarize the selection of the attributes
print(rfe.support_)
print(rfe.ranking_)
# Out:
# [False  True  True  True]
# [2 1 1 1]

# %%
import pandas as pd
import numpy as np
import time
import os  # Used to create folders
from sklearn.model_selection import train_test_split, KFold, cross_val_score
from sklearn.linear_model import LinearRegression, ElasticNet
from sklearn.kernel_ridge import KernelRidge
from sklearn.metrics import mean_squared_error, make_scorer
from sklearn.ensemble import RandomForestRegressor
from shutil import copyfile	 # Used to copy parameters file to directory
from sklearn.utils import resample
from read_parameter_file import get_parameters
from sklearn.feature_selection import RFE
# from xgboost import xgboost


parameters = "../../../Data/parameters.txt"	 # Parameters file
d = get_parameters(parameters)


if d["user"] == "Kieron":
    if d["specify_subfolder"] == "n":
        newpath = r"../0. Results/" + d["user"] + "/model/" + time.strftime("%Y.%m.%d/") + time.strftime("%H.%M.%S/")# Log file location
    else:
        newpath = r"../0. Results/" + d["user"] + "/model/" + d["specify_subfolder"] + time.strftime("/%Y.%m.%d/") + \
                  time.strftime("%H.%M.%S/")  # Log file location
else:
    newpath = r"../0. Results/" + d["user"] + "/model/" + time.strftime("%Y.%m.%d/")  # Log file location
if not os.path.exists(newpath):
    os.makedirs(newpath)  # Make folder for storing results if it does not exist

np.random.seed(int(d["seed"]))	# Set seed

if d["user"] == "Kieron":
    df = pd.read_csv(d["file_location"] + d["file_name"] + ".csv", encoding='latin-1', low_memory=False)
else:
    df = pd.read_csv(d["file_location"] + "vw_Incident_cleaned" + d["file_name"] + ".csv", encoding='latin-1',
                     low_memory=False)

if d["resample"] == "y":
        df = resample(df, n_samples=int(d["n_samples"]), random_state=int(d["seed"]))

X = df.drop("TimeTaken", axis=1)
y = df["TimeTaken"]

# Split the dataset in two equal parts
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=int(d["seed"]))


regressors = []
alg_names = []

if d["LinearRegression"] == "y":
    regressors.append(LinearRegression())
#     parameters_to_tune.append({
#         "fit_intercept":[True, False],
#         "normalize":[True, False]})
    alg_names.append("LinearRegression")
if d["ElasticNet"] == "y":
    regressors.append(ElasticNet())
#     parameters_to_tune.append({
#         # "alpha":[0.0001, 0.001, 0.01, 0.1, 1.0, 10, 100], # get convergence warning for small alphas
#         "alpha": [0.01, 0.01, 0.1, 1.0, 10, 100],
#         "l1_ratio":[.1, .5, .7, .9, .95, .99, 1],
#         "max_iter":[10000, 100000],
#          # "tol": [0.00001, 0.0001],
#          # "warm_start":[True, False]}
#     })
    alg_names.append("ElasticNet")
if d["KernelRidge"] == "y":
    regressors.append(KernelRidge(kernel='rbf', gamma=0.1))
#     parameters_to_tune.append({"alpha": [1e0, 0.1, 1e-2, 1e-3],
#                               "gamma": np.logspace(-2, 2, 5)})
    alg_names.append("KernelRidge")
# if d["xgboost"] == "y":
# 	regressors.append(GridSearchCV(xgboost())
# 	alg_names.append("xgboost")
if d["RandomForestRegressor"] == "y":
    regressors.append(RandomForestRegressor())
#     parameters_to_tune.append({
#         "n_estimators":[100, 250, 500, 1000],
#         "criterion":["mse", "mae"],
#         "max_features":[1, 0.1, "auto", "sqrt", "log2", None],
#         "max_depth":[None, 10, 25, 50]})
    alg_names.append("RandomForestRegressor")

if d["top_k_features"] == "y":
    k = None
else:
    k = int(d["top_k_features"])
if d["step"] == "y":
    step = 1
else:
    step = int(d["step"])
    
for regressor, alg_name in zip(regressors, alg_names):
    print("# %s Recursive Feature Elimination for top k = %s features (step = %s):\n" % (alg_name, k, step))
    regr = RFE(regressor, n_features_to_select=k, step=step)
    regr.fit(X_train, y_train.values.ravel())
    
    supports = regr.support_
    rankings = regr.ranking_
    
    kX_train = pd.Dataframe()
    for i, (ranking, support) in enumerate(zip(rankings, supports)):
        print(X_train.columns[i], ranking, support)
    
    print(regr.score(X_train, y_train))
    print(regr.score(X_test, y_test))
    
    
    

#     print(regr.score(y_test))
    
#     print("Best parameters set found on development set:")
#     print("\t", regr.best_params_)

#     best_train = regr.cv_results_["mean_train_score"][regr.best_index_]
#     best_train_std = regr.cv_results_["std_train_score"][regr.best_index_]
#     best_test = regr.cv_results_["mean_test_score"][regr.best_index_]
#     best_test_std = regr.cv_results_["std_test_score"][regr.best_index_]
#     print("\n\t R2 Train: %0.5f (+/- %0.05f)" % (best_train, best_train_std * 2))
#     print("\t R2 Test: %0.5f (+/- %0.05f)" % (best_test, best_test_std * 2))

#     y_train_pred = regr.predict(X_train)
#     mse_train = mean_squared_error(y_train, y_train_pred)
#     y_test_pred = regr.predict(X_test)
#     mse_test = mean_squared_error(y_test, y_test_pred)
#     print("\t RMSE Train: %s" % mse_train)
#     print("\t RMSE Test: %s" % mse_test)

#     with open(newpath + "best_params_%s" % alg_name + time.strftime("%H.%M.%S.txt"), "w") as f:
#         f.write("Best parameters set found on development set:\n")
#         f.write("\t"+str(regr.best_params_) + "\n")
#         f.write("\tTrain: %0.5f (+/- %0.05f)\n" % (best_train, best_train_std * 2))
#         f.write("\tTest: %0.5f (+/- %0.05f)\n" % (best_test, best_test_std * 2))
#         f.write("\t RMSE Train: %s\n" % mse_train)
#         f.write("\t RMSE Test: %s\n" % mse_test)

#         print("\nGrid R2 scores on development set:")
#         f.write("\nGrid R2 scores on development set:\n")
#         means = regr.cv_results_['mean_test_score']
#         stds = regr.cv_results_['std_test_score']
#         for mean, std, params in zip(means, stds, regr.cv_results_['params']):
#             f.write("\t%0.5f (+/-%0.05f) for %r\n" % (mean, std * 2, params))
#             print("\t%0.5f (+/-%0.05f) for %r" % (mean, std * 2, params))

# copyfile(parameters, newpath + "/" + time.strftime("%H.%M.%S") + "_parameters.txt")  # Save parameters
# Out:
# # LinearRegression Recursive Feature Elimination for top k = None features (step = 1):
#
# Reason_3PP - Identify Payment 1 True
# Reason_3PP - Other 1 True
# Reason_3PP - Payment Status 1 True
# Reason_3PP - Pending Payment 1 True
# Reason_3rd Party Hold 1 True
# Reason_A - Missing information from customer - Confirmation 1 True
# Reason_A - Missing information from customer - Missing information 1 True
# Reason_APOC - Waiting for document review 1 True
# Reason_Affiliates Section Error 1 True
# Reason_Agreement  Number Error 1 True
# Reason_Agreement - Bill To/Ship To Participant 1 True
# Reason_Agreement - Compliance 1 True
# Reason_Agreement - Paperwork Validation 1 True
# Reason_Agreement /Enrollment Number Error 1 True
# Reason_Agreement/Enrollment Number Error 1 True
# Reason_Agreement/Enrollment Number Issue 1 True
# Reason_Agreement/Enrollment Number/Date Issue 1 True
# Reason_Agreement/Enrollment Number/Name  Issue 1 True
# Reason_Amendment - Amendment Description 1 True
# Reason_Amendment - Other 1 True
# Reason_Amendment Completion Error 1 True
# Reason_Approval - Business - Delegation 1 True
# Reason_Approval - ROC - Exception 1 True
# Reason_Audience Manager  - Approval required for credit & rebill request 1 True
# Reason_Audience Manager  - Policy clarification/Complex Query 1 True
# Reason_Audience Manager  - Product related 1 True
# Reason_Audience Manager  - Query held open on PM Request 1 True
# Reason_Audience Manager  - Standard Approval 1 True
# Reason_Audience Manager  - System & Tools related 1 True
# Reason_Azure OLS - Approval required for credit & rebill request 1 True
# Reason_Azure OLS - Approval required for final fee 1 True
# Reason_Billing Option Error 1 True
# Reason_CP Requested - N/A 1 True
# Reason_Cancel Order - Duplication 1 True
# Reason_Cancel Order - N/A 1 True
# Reason_Clarification 1 True
# Reason_Clarification Needed 1 True
# Reason_Clarification on Price 1 True
# Reason_Collections - Waiting for Amendment Approval 1 True
# Reason_Collections - Waiting for Credit Approval 1 True
# Reason_Compliance - Clarification Needed 1 True
# Reason_Compliance Error 1 True
# Reason_Compliance Issue 1 True
# Reason_Contact Details Error 1 True
# Reason_Credit & Collections Issues - Channel Partner on Credit Hold 1 True
# Reason_Credit Check Error 1 True
# Reason_Credit Services 1 True
# Reason_Credit Services - Clarification Needed 1 True
# Reason_Credit Services - Credit Approval 1 True
# Reason_Credit Services - Invoice Issue 1 True
# Reason_Credit Services - Partner on hold 1 True
# Reason_Credit Services - SAP 1 True
# Reason_Customer/Partner Credit Hold 1 True
# Reason_DD-Waiting on Customer Signature 1 True
# Reason_Document Code Error 1 True
# Reason_Document Description Error 1 True
# Reason_Duplicate Case - Duplicate case 1 True
# Reason_Duplicate Order 1 True
# Reason_E-Agreement Tool - Other 1 True
# Reason_EOC - Waiting for document review 1 True
# Reason_Electronic Order - Simple 1 True
# Reason_End Customer Contact Details Error 1 True
# Reason_End Customer Signature Block Issue 1 True
# Reason_End Customer/Partner Signature Block Issue 1 True
# Reason_End of Term Date Error 1 True
# Reason_Enrollment # Error 1 True
# Reason_Field - Clarification Needed 1 True
# Reason_Field - DD-Awaiting information from Field 26 False
# Reason_Field - DD-Clarification Needed 28 False
# Reason_Field - DD-Waiting for Paperwork 30 False
# Reason_Field - Waiting for Clarification 1 True
# Reason_Field Invalid-AMENDMENT (STD/CTM)-Required and Missing - Field 33 False
# Reason_Field Invalid-AMENDMENT(STD/CTM)-Completion Error - Field 35 False
# Reason_Field Invalid-CPS-Pricing, Quantity or Amount Error - Field 3 False
# Reason_Field Invalid-CPS-SKU Description Error - Field 5 False
# Reason_Field Invalid-Standard Policy Error w/o Empowerment - Field 7 False
# Reason_Field-AMENDMENT(STD/CTM)-Completion Error - Field 9 False
# Reason_Field-Amendment-Clarification Needed - Amendment Clarification Needed 11 False
# Reason_Field-CPS-Clarification Needed - CPS Clarification Needed 13 False
# Reason_Field-CPS-Header Error - Field 15 False
# Reason_Field-CPS-Notes Error - Field 17 False
# Reason_Field-CPS-Other Error - Field 19 False
# Reason_Field-MOPETApprovals-Approval Error - Field 21 False
# Reason_Field-MOPETApprovals-Hard/Soft Copy Error - Field 23 False
# Reason_Field-MOPETApprovals-Not Posted - Field 1 True
# Reason_Field-Other Custom Document Error - Field 61 False
# Reason_Field-Pricing Transparency Form - Missing/Incomplete Document 63 False
# Reason_Form not submitted pre-submission 65 False
# Reason_Forms 67 False
# Reason_Global Program Manager - Policy clarification/Complex Query 69 False
# Reason_Incomplete/ Inaccurate Information 71 False
# Reason_Incorrect Document Version 73 False
# Reason_Internal Hold - MOET & Msops Approvers 37 False
# Reason_Internal Hold - Ops PM 39 False
# Reason_Internal Hold - SME 58 False
# Reason_Internal Hold - Team Lead 41 False
# Reason_Internal Hold - Translations 43 False
# Reason_Internal Hold - VL Processing Team 45 False
# Reason_MOPET - Other 46 False
# Reason_MSL/EMSL - Incorrect Billing Multiplier 49 False
# Reason_MSL/EMSL - Incorrect Coverage 51 False
# Reason_MSL/EMSL - Other 53 False
# Reason_MSL/EMSL - Split Invoices 55 False
# Reason_Magnum 1 True
# Reason_Missing Documents 75 False
# Reason_Missing Final TUP/Update Statement 95 False
# Reason_Missing or Incorrect Documents 97 False
# Reason_Missing signatures 99 False
# Reason_Missing/Incomplete Document 98 False
# Reason_Need Approval - Other 1 True
# Reason_Need Approval - PO Number 79 False
# Reason_Need Approval - Signature Form 81 False
# Reason_Need Document - Agreement 83 False
# Reason_Need Document - Credit Request Form 85 False
# Reason_Need Document - Customer Letter 87 False
# Reason_Need Document - Missing Physical Invoice 1 True
# Reason_Need Document - Other 1 True
# Reason_Need Document - PO 141 False
# Reason_Need Document - Signature Form 109 False
# Reason_Need Info/Clarification/Correction 107 False
# Reason_Need Info/Clarification/Correction - 2nd Strike 111 False
# Reason_Need Info/Clarification/Correction - 3rd Strike 113 False
# Reason_Need Info/Clarification/Correction - Adjustment reason 115 False
# Reason_Need Info/Clarification/Correction - Agreement 117 False
# Reason_Need Info/Clarification/Correction - Closed - CH Unresolved 119 False
# Reason_Need Info/Clarification/Correction - Customer request unclear 121 False
# Reason_Need Info/Clarification/Correction - Escalation/Other 123 False
# Reason_Need Info/Clarification/Correction - Forms are altered 125 False
# Reason_Need Info/Clarification/Correction - Forms are not visible 127 False
# Reason_Need Info/Clarification/Correction - Incomplete Documents 129 False
# Reason_Need Info/Clarification/Correction - Invoice number 131 False
# Reason_Need Info/Clarification/Correction - Missing Enrollment Number 143 False
# Reason_Need Info/Clarification/Correction - Needs Definition 145 False
# Reason_Need Info/Clarification/Correction - Other 147 False
# Reason_Need Info/Clarification/Correction - PCN 148 False
# Reason_Need Info/Clarification/Correction - PO Number 133 False
# Reason_Need Info/Clarification/Correction - Resolution Confirmation 135 False
# Reason_Need Info/Clarification/Correction - Screenshots 137 False
# Reason_Need Info/Clarification/Correction - Signature Form 139 False
# Reason_Need Info/Clarification/Correction - System Error 142 False
# Reason_OAM - Approval request  (Mainly GRT/RMA) 101 False
# Reason_OAM - Information Request 149 False
# Reason_OAM - Order related 151 False
# Reason_OAM - Routed for Credit Approval 153 False
# Reason_OLS Hub - Unknown Query Response 103 False
# Reason_Offering Error 1 True
# Reason_OpsPM - Policy/Program clarification 106 False
# Reason_OpsPM - Process clarification 1 True
# Reason_Order - Billing Date 1 True
# Reason_Order - Billing Option 1 True
# Reason_Order - Billing Type 89 False
# Reason_Order - Compliance not flipped 1 True
# Reason_Order - Coverage - Incorrect Usage Date 1 True
# Reason_Order - Coverage - Tier 2 1 True
# Reason_Order - Coverage Period 77 False
# Reason_Order - Credit Hold 93 False
# Reason_Order - Duplicate 154 False
# Reason_Order - Incorrect Agreement 57 False
# Reason_Order - License Reduction not processed 25 False
# Reason_Order - License Reduction processed incorrectly 91 False
# Reason_Order - Other 1 True
# Reason_Order - PO Number 1 True
# Reason_Order - PO Type 1 True
# Reason_Order - Paperwork Validation 1 True
# Reason_Order - Pre-requisites Missing 1 True
# Reason_Order - Price 155 False
# Reason_Order - Price - Anniversary order 157 False
# Reason_Order - Price - CPS 159 False
# Reason_Order - Price - Price List 161 False
# Reason_Order - Price - Proration 163 False
# Reason_Order - Price/Currency 165 False
# Reason_Order - Quanity 167 False
# Reason_Order - SKU 169 False
# Reason_Order - Usage Country 171 False
# Reason_Order - Usage Date 173 False
# Reason_Order - Usage Date/Coverage 175 False
# Reason_Order - Wrong Program offering 177 False
# Reason_Order ? Bridge SKU Coverage processed incorrectly 179 False
# Reason_Order ? License Reservation(s) not reconciled 178 False
# Reason_Other 176 False
# Reason_Other - Agreement 174 False
# Reason_Other - Other 1 True
# Reason_Other - Signature Form 152 False
# Reason_Other CPS Completion Error 150 False
# Reason_Other Completion error 1 True
# Reason_Other Enrollment Completion Error 146 False
# Reason_Other Manual PO completion Error 1 True
# Reason_Other PLT Completion Error 140 False
# Reason_Other PSF Completion Error 138 False
# Reason_Other Signature Form Error 136 False
# Reason_PO Number Error 134 False
# Reason_PO Type Error 132 False
# Reason_Package Triage form - Unable to Close Form 130 False
# Reason_Part Number/Description Error 128 False
# Reason_Partner 126 False
# Reason_Partner Business Desk - Approval required for credit & rebill request 124 False
# Reason_Partner Business Desk - Override Approval Review/Confirmation 122 False
# Reason_Partner Business Desk - Program/Policy Clarification 120 False
# Reason_Partner Risk - Account Query - General 118 False
# Reason_Previous Enrollment Detail Error 116 False
# Reason_Price Error 114 False
# Reason_Price Level or Customer Commitment Error 112 False
# Reason_Pricing 110 False
# Reason_Pricing Team - Clarification Needed 108 False
# Reason_Pricing Team - Price verification 1 True
# Reason_Pricing Team - Replacement sku verification 96 False
# Reason_Product/Price Level Determination Error 94 False
# Reason_Proposal ID error 92 False
# Reason_Purchase Order Type Error 90 False
# Reason_Quantity Error 88 False
# Reason_Quantity Error v CPS 86 False
# Reason_RO Tool - Billing option 84 False
# Reason_Reason for Manual Order Error 82 False
# Reason_Regional Program Manager - Adjustment Approval 80 False
# Reason_Regional Program Manager - Exception Approval 78 False
# Reason_Regional Program Manager - Exception Request 76 False
# Reason_Regional Program Manager - Manual Order Approval 74 False
# Reason_Regional Program Manager - Order related 72 False
# Reason_Rework - Other 70 False
# Reason_Rework - Rebill / Rework Incorrect 68 False
# Reason_SAP - Account Holds 66 False
# Reason_SAP - Other 64 False
# Reason_SKU Description Error 62 False
# Reason_SUB - Approval 60 False
# Reason_SUB - Clarification Needed 56 False
# Reason_SUB - Other 54 False
# Reason_Signature 52 False
# Reason_Signature Block Error 50 False
# Reason_Standard Policy Error w/o Empowerment 48 False
# Reason_Subscription Term Error 44 False
# Reason_Subsidiary Invalid - Standard Policy Error w/o Empowerment 42 False
# Reason_System Issue 40 False
# Reason_Systems - BART issue 38 False
# Reason_Systems - Chip Help - Other 36 False
# Reason_Systems - Docusign - System issues 34 False
# Reason_Systems - EDI/XML issue 32 False
# Reason_Systems - EOLAS Issue 24 False
# Reason_Systems - Explore ms - System issues 22 False
# Reason_Systems - Global Sales Support - System issue 20 False
# Reason_Systems - LIR - Awaiting data insertion into LIR 18 False
# Reason_Systems - MIMOS - System issue 16 False
# Reason_Systems - MOET Issue 14 False
# Reason_Systems - MSL - Backend Correction 12 False
# Reason_Systems - MSL - Contract cannot be activated 10 False
# Reason_Systems - No Access to Tool 8 False
# Reason_Systems - Papervision - System issues 6 False
# Reason_Systems - Partner Quotes issue 4 False
# Reason_Systems - SAP - Access issue/request 2 False
# Reason_Systems - SAP - Change CP contact info in SAP 1 True
# Reason_Systems - SAP - Reports request 1 True
# Reason_Systems - System Issue 1 True
# Reason_Systems - Unknown Query Response 1 True
# Reason_Systems - VLCM Issue 1 True
# Reason_Systems - VLSC Issue 1 True
# Reason_Systems - eMSL Issue 1 True
# Reason_Tax - Clarification Needed 1 True
# Reason_Tax - Sales and Use Tax Issue 1 True
# Reason_Tax - Tax Adjustment 1 True
# Reason_Tax - Tax Credit Approval 1 True
# Reason_Tax - Waiting for tax exempt form approval 1 True
# Reason_Tier 2 - Tier 2 - Waiting for MSL backend correction 1 True
# Reason_Trade - Trade Status Hold 1 True
# Reason_Usage Country Error 1 True
# Reason_Usage Date Error 1 True
# Reason_VLCM - Agreement failed to activate 1 True
# Reason_WWLP - Verify Fee Calculation 1 True
# Reason_Waiting for Sub-Signature 1 True
# Reason_Workbench 1 True
# Reason_X - LIR - Awaiting data insertion into LIR 1 True
# AssignedToGroup_CRMT 1 True
# AssignedToGroup_Internal 1 True
# AssignedToGroup_Microsoft IT 1 True
# AssignedToGroup_Ops. Program Manager 1 True
# AssignedToGroup_Submitter (Contact) 1 True
# NewValueName_Ops In 1 True
# NewValueName_Ops Out 1 True
# NewValueName_Submission 1 True
# NewValueName_Triage And Validation 1 True
# OldValueName_Ops In 1 True
# OldValueName_Ops Out 1 True
# OldValueName_Submission 1 True
# OldValueName_Triage And Validation 1 True
# AmountinUSD 1 True
# Complexity 1 True
# CountryProcessed_asia 1 True
# CountryProcessed_australia 27 False
# CountryProcessed_europe 1 True
# CountryProcessed_northamerica 1 True
# CountryProcessed_other 29 False
# CountryProcessed_southamerica 1 True
# CountrySource_asia 1 True
# CountrySource_australia 31 False
# CountrySource_europe 1 True
# CountrySource_northamerica 1 True
# CountrySource_other 1 True
# CountrySource_southamerica 1 True
# IsGovernment 1 True
# IsMagnumCase 1 True
# IsSOXCase 1 True
# IsSignature 1 True
# Numberofreactivations 100 False
# OLSRevenue 1 True
# Priority 1 True
# Queue_AOC 1 True
# Queue_APOC 1 True
# Queue_EOC 1 True
# Queue_LOC 47 False
# Queue_NAOC 1 True
# ROCName_APOC 1 True
# ROCName_EOC 1 True
# Revenutype_Credit / Rebill 1 True
# Revenutype_Current Revenue 1 True
# Revenutype_Disputed Revenue 1 True
# Revenutype_Future Billing 1 True
# Revenutype_Future OTRRR with OLS 1 True
# Revenutype_Future OTRRR without OLS 1 True
# Revenutype_New Work Sold 1 True
# Revenutype_Non-revenue 1 True
# Revenutype_Revenue Impacting Case / Pending Revenue 1 True
# Revenutype_Revenue Unknown 1 True
# SalesLocation_asia 1 True
# SalesLocation_australia 1 True
# SalesLocation_europe 1 True
# SalesLocation_northamerica 1 True
# SalesLocation_southamerica 1 True
# Source_Fax 1 True
# Source_Hard Copy 1 True
# Source_Manual 1 True
# Source_Soft Copy 1 True
# Source_Web 1 True
# Source_eAgreement (Ele) 102 False
# Source_eAgreement (Phy) 104 False
# StageName_Ops In 1 True
# StageName_Ops Out 1 True
# StageName_Submission 1 True
# StageName_Triage And Validation 144 False
# StatusReason_Information Provided 105 False
# StatusReason_Problem Solved 1 True
# SubReason_Basic Enterprise Commitment 1 True
# SubReason_Electronic Order Pend / Reject 1 True
# SubReason_Future Pricing Only CPS 1 True
# SubReason_Manual Order Entry 1 True
# SubReason_Meteaop 1 True
# SubReason_P&H Electronic Order 59 False
# SubReason_Tax Exemption Order 1 True
# SubReason_True Up 1 True
# SubReason_Zero Usage Order 1 True
# sourcesystem_Aplquest 156 False
# sourcesystem_CLT 158 False
# sourcesystem_Current Revenue 160 False
# sourcesystem_Moritz Jürgensen 162 False
# sourcesystem_NEMEC 164 False
# sourcesystem_NMEC 166 False
# sourcesystem_Web 168 False
# sourcesystem_clt 170 False
# sourcesystem_web 172 False
# 0.991741710103
# -4.11291971115
# 356
# 356
# 178

# %% [markdown]
# #### want to be able to call a function in model.py that takes in the regressor, runs it once with RFE and then runs it again with k featuress

# %%
from sklearn.feature_selection import RFE
def RFE_modeling(regressor, k, step,d, X_train, y_train, X_test, y_test):
    
    if d["top_k_features"] == "y":
        k = None
    else:
        k = int(d["top_k_features"])
    if d["step"] == "y":
        step = 1
    else:
        step = int(d["step"])    
    
    regr = RFE(regressor, n_features_to_select=k, step=step)
    regr.fit(X_train, y_train.values.ravel())
    
    print("train score (all features): ", regr.score(X_train, y_train))
    print("test score (all features): ", regr.score(X_test, y_test), "\n")
    
    supports = regr.support_
    rankings = regr.ranking_
    
    kX_train = pd.DataFrame()
    kX_test = pd.DataFrame()
    for i, (ranking, support) in enumerate(zip(rankings, supports)):
        print("Used: %s, Ranking: %s, Column name: %s"% (support, ranking, X_train.columns[i]))
        if support == True:
            kX_train[X_train.columns[i]] = X_train[X_train.columns[i]]
            kX_test[X_train.columns[i]] = X_test[X_train.columns[i]]
    
    regressor.fit(kX_train, y_train.values.ravel())
    
    if k is None:
        print("\ntrain score (k = half features and step = %s): " % step, regressor.score(kX_train, y_train))
        print("test score: (k = half features and step = %s): " % step, regressor.score(kX_test, y_test))
    else:
        print("\ntrain score (k = %s features and step = %s): " % (k, step), regressor.score(kX_train, y_train))
        print("test score: (k = %s features and step = %s): " % (k, step), regressor.score(kX_test, y_test))
    return kX_train, kX_test
    
RFE_modeling(LinearRegression(), k, step, d, X_train, y_train, X_test, y_test)
# Out:
# train score (all features):  0.991741710103
# test score (all features):  -4.11291971115
#
# Used: True, Ranking: 1, Column name: Reason_3PP - Identify Payment
# Used: True, Ranking: 1, Column name: Reason_3PP - Other
# Used: True, Ranking: 1, Column name: Reason_3PP - Payment Status
# Used: True, Ranking: 1, Column name: Reason_3PP - Pending Payment
# Used: True, Ranking: 1, Column name: Reason_3rd Party Hold
# Used: True, Ranking: 1, Column name: Reason_A - Missing information from customer - Confirmation
# Used: True, Ranking: 1, Column name: Reason_A - Missing information from customer - Missing information
# Used: True, Ranking: 1, Column name: Reason_APOC - Waiting for document review
# Used: True, Ranking: 1, Column name: Reason_Affiliates Section Error
# Used: True, Ranking: 1, Column name: Reason_Agreement  Number Error
# Used: True, Ranking: 1, Column name: Reason_Agreement - Bill To/Ship To Participant
# Used: True, Ranking: 1, Column name: Reason_Agreement - Compliance
# Used: True, Ranking: 1, Column name: Reason_Agreement - Paperwork Validation
# Used: True, Ranking: 1, Column name: Reason_Agreement /Enrollment Number Error
# Used: True, Ranking: 1, Column name: Reason_Agreement/Enrollment Number Error
# Used: True, Ranking: 1, Column name: Reason_Agreement/Enrollment Number Issue
# Used: True, Ranking: 1, Column name: Reason_Agreement/Enrollment Number/Date Issue
# Used: True, Ranking: 1, Column name: Reason_Agreement/Enrollment Number/Name  Issue
# Used: True, Ranking: 1, Column name: Reason_Amendment - Amendment Description
# Used: True, Ranking: 1, Column name: Reason_Amendment - Other
# Used: True, Ranking: 1, Column name: Reason_Amendment Completion Error
# Used: True, Ranking: 1, Column name: Reason_Approval - Business - Delegation
# Used: True, Ranking: 1, Column name: Reason_Approval - ROC - Exception
# Used: True, Ranking: 1, Column name: Reason_Audience Manager  - Approval required for credit & rebill request
# Used: True, Ranking: 1, Column name: Reason_Audience Manager  - Policy clarification/Complex Query
# Used: True, Ranking: 1, Column name: Reason_Audience Manager  - Product related
# Used: True, Ranking: 1, Column name: Reason_Audience Manager  - Query held open on PM Request
# Used: True, Ranking: 1, Column name: Reason_Audience Manager  - Standard Approval
# Used: True, Ranking: 1, Column name: Reason_Audience Manager  - System & Tools related
# Used: True, Ranking: 1, Column name: Reason_Azure OLS - Approval required for credit & rebill request
# Used: True, Ranking: 1, Column name: Reason_Azure OLS - Approval required for final fee
# Used: True, Ranking: 1, Column name: Reason_Billing Option Error
# Used: True, Ranking: 1, Column name: Reason_CP Requested - N/A
# Used: True, Ranking: 1, Column name: Reason_Cancel Order - Duplication
# Used: True, Ranking: 1, Column name: Reason_Cancel Order - N/A
# Used: True, Ranking: 1, Column name: Reason_Clarification
# Used: True, Ranking: 1, Column name: Reason_Clarification Needed
# Used: True, Ranking: 1, Column name: Reason_Clarification on Price
# Used: True, Ranking: 1, Column name: Reason_Collections - Waiting for Amendment Approval
# Used: True, Ranking: 1, Column name: Reason_Collections - Waiting for Credit Approval
# Used: True, Ranking: 1, Column name: Reason_Compliance - Clarification Needed
# Used: True, Ranking: 1, Column name: Reason_Compliance Error
# Used: True, Ranking: 1, Column name: Reason_Compliance Issue
# Used: True, Ranking: 1, Column name: Reason_Contact Details Error
# Used: True, Ranking: 1, Column name: Reason_Credit & Collections Issues - Channel Partner on Credit Hold
# Used: True, Ranking: 1, Column name: Reason_Credit Check Error
# Used: True, Ranking: 1, Column name: Reason_Credit Services
# Used: True, Ranking: 1, Column name: Reason_Credit Services - Clarification Needed
# Used: True, Ranking: 1, Column name: Reason_Credit Services - Credit Approval
# Used: True, Ranking: 1, Column name: Reason_Credit Services - Invoice Issue
# Used: True, Ranking: 1, Column name: Reason_Credit Services - Partner on hold
# Used: True, Ranking: 1, Column name: Reason_Credit Services - SAP
# Used: True, Ranking: 1, Column name: Reason_Customer/Partner Credit Hold
# Used: True, Ranking: 1, Column name: Reason_DD-Waiting on Customer Signature
# Used: True, Ranking: 1, Column name: Reason_Document Code Error
# Used: True, Ranking: 1, Column name: Reason_Document Description Error
# Used: True, Ranking: 1, Column name: Reason_Duplicate Case - Duplicate case
# Used: True, Ranking: 1, Column name: Reason_Duplicate Order
# Used: True, Ranking: 1, Column name: Reason_E-Agreement Tool - Other
# Used: True, Ranking: 1, Column name: Reason_EOC - Waiting for document review
# Used: True, Ranking: 1, Column name: Reason_Electronic Order - Simple
# Used: True, Ranking: 1, Column name: Reason_End Customer Contact Details Error
# Used: True, Ranking: 1, Column name: Reason_End Customer Signature Block Issue
# Used: True, Ranking: 1, Column name: Reason_End Customer/Partner Signature Block Issue
# Used: True, Ranking: 1, Column name: Reason_End of Term Date Error
# Used: True, Ranking: 1, Column name: Reason_Enrollment # Error
# Used: True, Ranking: 1, Column name: Reason_Field - Clarification Needed
# Used: False, Ranking: 26, Column name: Reason_Field - DD-Awaiting information from Field
# Used: False, Ranking: 28, Column name: Reason_Field - DD-Clarification Needed
# Used: False, Ranking: 30, Column name: Reason_Field - DD-Waiting for Paperwork
# Used: True, Ranking: 1, Column name: Reason_Field - Waiting for Clarification
# Used: False, Ranking: 33, Column name: Reason_Field Invalid-AMENDMENT (STD/CTM)-Required and Missing - Field
# Used: False, Ranking: 35, Column name: Reason_Field Invalid-AMENDMENT(STD/CTM)-Completion Error - Field
# Used: False, Ranking: 3, Column name: Reason_Field Invalid-CPS-Pricing, Quantity or Amount Error - Field
# Used: False, Ranking: 5, Column name: Reason_Field Invalid-CPS-SKU Description Error - Field
# Used: False, Ranking: 7, Column name: Reason_Field Invalid-Standard Policy Error w/o Empowerment - Field
# Used: False, Ranking: 9, Column name: Reason_Field-AMENDMENT(STD/CTM)-Completion Error - Field
# Used: False, Ranking: 11, Column name: Reason_Field-Amendment-Clarification Needed - Amendment Clarification Needed
# Used: False, Ranking: 13, Column name: Reason_Field-CPS-Clarification Needed - CPS Clarification Needed
# Used: False, Ranking: 15, Column name: Reason_Field-CPS-Header Error - Field
# Used: False, Ranking: 17, Column name: Reason_Field-CPS-Notes Error - Field
# Used: False, Ranking: 19, Column name: Reason_Field-CPS-Other Error - Field
# Used: False, Ranking: 21, Column name: Reason_Field-MOPETApprovals-Approval Error - Field
# Used: False, Ranking: 23, Column name: Reason_Field-MOPETApprovals-Hard/Soft Copy Error - Field
# Used: True, Ranking: 1, Column name: Reason_Field-MOPETApprovals-Not Posted - Field
# Used: False, Ranking: 61, Column name: Reason_Field-Other Custom Document Error - Field
# Used: False, Ranking: 63, Column name: Reason_Field-Pricing Transparency Form - Missing/Incomplete Document
# Used: False, Ranking: 65, Column name: Reason_Form not submitted pre-submission
# Used: False, Ranking: 67, Column name: Reason_Forms
# Used: False, Ranking: 69, Column name: Reason_Global Program Manager - Policy clarification/Complex Query
# Used: False, Ranking: 71, Column name: Reason_Incomplete/ Inaccurate Information
# Used: False, Ranking: 73, Column name: Reason_Incorrect Document Version
# Used: False, Ranking: 37, Column name: Reason_Internal Hold - MOET & Msops Approvers
# Used: False, Ranking: 39, Column name: Reason_Internal Hold - Ops PM
# Used: False, Ranking: 58, Column name: Reason_Internal Hold - SME
# Used: False, Ranking: 41, Column name: Reason_Internal Hold - Team Lead
# Used: False, Ranking: 43, Column name: Reason_Internal Hold - Translations
# Used: False, Ranking: 45, Column name: Reason_Internal Hold - VL Processing Team
# Used: False, Ranking: 46, Column name: Reason_MOPET - Other
# Used: False, Ranking: 49, Column name: Reason_MSL/EMSL - Incorrect Billing Multiplier
# Used: False, Ranking: 51, Column name: Reason_MSL/EMSL - Incorrect Coverage
# Used: False, Ranking: 53, Column name: Reason_MSL/EMSL - Other
# Used: False, Ranking: 55, Column name: Reason_MSL/EMSL - Split Invoices
# Used: True, Ranking: 1, Column name: Reason_Magnum
# Used: False, Ranking: 75, Column name: Reason_Missing Documents
# Used: False, Ranking: 95, Column name: Reason_Missing Final TUP/Update Statement
# Used: False, Ranking: 97, Column name: Reason_Missing or Incorrect Documents
# Used: False, Ranking: 99, Column name: Reason_Missing signatures
# Used: False, Ranking: 98, Column name: Reason_Missing/Incomplete Document
# Used: True, Ranking: 1, Column name: Reason_Need Approval - Other
# Used: False, Ranking: 79, Column name: Reason_Need Approval - PO Number
# Used: False, Ranking: 81, Column name: Reason_Need Approval - Signature Form
# Used: False, Ranking: 83, Column name: Reason_Need Document - Agreement
# Used: False, Ranking: 85, Column name: Reason_Need Document - Credit Request Form
# Used: False, Ranking: 87, Column name: Reason_Need Document - Customer Letter
# Used: True, Ranking: 1, Column name: Reason_Need Document - Missing Physical Invoice
# Used: True, Ranking: 1, Column name: Reason_Need Document - Other
# Used: False, Ranking: 141, Column name: Reason_Need Document - PO
# Used: False, Ranking: 109, Column name: Reason_Need Document - Signature Form
# Used: False, Ranking: 107, Column name: Reason_Need Info/Clarification/Correction
# Used: False, Ranking: 111, Column name: Reason_Need Info/Clarification/Correction - 2nd Strike
# Used: False, Ranking: 113, Column name: Reason_Need Info/Clarification/Correction - 3rd Strike
# Used: False, Ranking: 115, Column name: Reason_Need Info/Clarification/Correction - Adjustment reason
# Used: False, Ranking: 117, Column name: Reason_Need Info/Clarification/Correction - Agreement
# Used: False, Ranking: 119, Column name: Reason_Need Info/Clarification/Correction - Closed - CH Unresolved
# Used: False, Ranking: 121, Column name: Reason_Need Info/Clarification/Correction - Customer request unclear
# Used: False, Ranking: 123, Column name: Reason_Need Info/Clarification/Correction - Escalation/Other
# Used: False, Ranking: 125, Column name: Reason_Need Info/Clarification/Correction - Forms are altered
# Used: False, Ranking: 127, Column name: Reason_Need Info/Clarification/Correction - Forms are not visible
# Used: False, Ranking: 129, Column name: Reason_Need Info/Clarification/Correction - Incomplete Documents
# Used: False, Ranking: 131, Column name: Reason_Need Info/Clarification/Correction - Invoice number
# Used: False, Ranking: 143, Column name: Reason_Need Info/Clarification/Correction - Missing Enrollment Number
# Used: False, Ranking: 145, Column name: Reason_Need Info/Clarification/Correction - Needs Definition
# Used: False, Ranking: 147, Column name: Reason_Need Info/Clarification/Correction - Other
# Used: False, Ranking: 148, Column name: Reason_Need Info/Clarification/Correction - PCN
# Used: False, Ranking: 133, Column name: Reason_Need Info/Clarification/Correction - PO Number
# Used: False, Ranking: 135, Column name: Reason_Need Info/Clarification/Correction - Resolution Confirmation
# Used: False, Ranking: 137, Column name: Reason_Need Info/Clarification/Correction - Screenshots
# Used: False, Ranking: 139, Column name: Reason_Need Info/Clarification/Correction - Signature Form
# Used: False, Ranking: 142, Column name: Reason_Need Info/Clarification/Correction - System Error
# Used: False, Ranking: 101, Column name: Reason_OAM - Approval request  (Mainly GRT/RMA)
# Used: False, Ranking: 149, Column name: Reason_OAM - Information Request
# Used: False, Ranking: 151, Column name: Reason_OAM - Order related
# Used: False, Ranking: 153, Column name: Reason_OAM - Routed for Credit Approval
# Used: False, Ranking: 103, Column name: Reason_OLS Hub - Unknown Query Response
# Used: True, Ranking: 1, Column name: Reason_Offering Error
# Used: False, Ranking: 106, Column name: Reason_OpsPM - Policy/Program clarification
# Used: True, Ranking: 1, Column name: Reason_OpsPM - Process clarification
# Used: True, Ranking: 1, Column name: Reason_Order - Billing Date
# Used: True, Ranking: 1, Column name: Reason_Order - Billing Option
# Used: False, Ranking: 89, Column name: Reason_Order - Billing Type
# Used: True, Ranking: 1, Column name: Reason_Order - Compliance not flipped
# Used: True, Ranking: 1, Column name: Reason_Order - Coverage - Incorrect Usage Date
# Used: True, Ranking: 1, Column name: Reason_Order - Coverage - Tier 2
# Used: False, Ranking: 77, Column name: Reason_Order - Coverage Period
# Used: False, Ranking: 93, Column name: Reason_Order - Credit Hold
# Used: False, Ranking: 154, Column name: Reason_Order - Duplicate
# Used: False, Ranking: 57, Column name: Reason_Order - Incorrect Agreement
# Used: False, Ranking: 25, Column name: Reason_Order - License Reduction not processed
# Used: False, Ranking: 91, Column name: Reason_Order - License Reduction processed incorrectly
# Used: True, Ranking: 1, Column name: Reason_Order - Other
# Used: True, Ranking: 1, Column name: Reason_Order - PO Number
# Used: True, Ranking: 1, Column name: Reason_Order - PO Type
# Used: True, Ranking: 1, Column name: Reason_Order - Paperwork Validation
# Used: True, Ranking: 1, Column name: Reason_Order - Pre-requisites Missing
# Used: False, Ranking: 155, Column name: Reason_Order - Price
# Used: False, Ranking: 157, Column name: Reason_Order - Price - Anniversary order
# Used: False, Ranking: 159, Column name: Reason_Order - Price - CPS
# Used: False, Ranking: 161, Column name: Reason_Order - Price - Price List
# Used: False, Ranking: 163, Column name: Reason_Order - Price - Proration
# Used: False, Ranking: 165, Column name: Reason_Order - Price/Currency
# Used: False, Ranking: 167, Column name: Reason_Order - Quanity
# Used: False, Ranking: 169, Column name: Reason_Order - SKU
# Used: False, Ranking: 171, Column name: Reason_Order - Usage Country
# Used: False, Ranking: 173, Column name: Reason_Order - Usage Date
# Used: False, Ranking: 175, Column name: Reason_Order - Usage Date/Coverage
# Used: False, Ranking: 177, Column name: Reason_Order - Wrong Program offering
# Used: False, Ranking: 179, Column name: Reason_Order ? Bridge SKU Coverage processed incorrectly
# Used: False, Ranking: 178, Column name: Reason_Order ? License Reservation(s) not reconciled
# Used: False, Ranking: 176, Column name: Reason_Other
# Used: False, Ranking: 174, Column name: Reason_Other - Agreement
# Used: True, Ranking: 1, Column name: Reason_Other - Other
# Used: False, Ranking: 152, Column name: Reason_Other - Signature Form
# Used: False, Ranking: 150, Column name: Reason_Other CPS Completion Error
# Used: True, Ranking: 1, Column name: Reason_Other Completion error
# Used: False, Ranking: 146, Column name: Reason_Other Enrollment Completion Error
# Used: True, Ranking: 1, Column name: Reason_Other Manual PO completion Error
# Used: False, Ranking: 140, Column name: Reason_Other PLT Completion Error
# Used: False, Ranking: 138, Column name: Reason_Other PSF Completion Error
# Used: False, Ranking: 136, Column name: Reason_Other Signature Form Error
# Used: False, Ranking: 134, Column name: Reason_PO Number Error
# Used: False, Ranking: 132, Column name: Reason_PO Type Error
# Used: False, Ranking: 130, Column name: Reason_Package Triage form - Unable to Close Form
# Used: False, Ranking: 128, Column name: Reason_Part Number/Description Error
# Used: False, Ranking: 126, Column name: Reason_Partner
# Used: False, Ranking: 124, Column name: Reason_Partner Business Desk - Approval required for credit & rebill request
# Used: False, Ranking: 122, Column name: Reason_Partner Business Desk - Override Approval Review/Confirmation
# Used: False, Ranking: 120, Column name: Reason_Partner Business Desk - Program/Policy Clarification
# Used: False, Ranking: 118, Column name: Reason_Partner Risk - Account Query - General
# Used: False, Ranking: 116, Column name: Reason_Previous Enrollment Detail Error
# Used: False, Ranking: 114, Column name: Reason_Price Error
# Used: False, Ranking: 112, Column name: Reason_Price Level or Customer Commitment Error
# Used: False, Ranking: 110, Column name: Reason_Pricing
# Used: False, Ranking: 108, Column name: Reason_Pricing Team - Clarification Needed
# Used: True, Ranking: 1, Column name: Reason_Pricing Team - Price verification
# Used: False, Ranking: 96, Column name: Reason_Pricing Team - Replacement sku verification
# Used: False, Ranking: 94, Column name: Reason_Product/Price Level Determination Error
# Used: False, Ranking: 92, Column name: Reason_Proposal ID error
# Used: False, Ranking: 90, Column name: Reason_Purchase Order Type Error
# Used: False, Ranking: 88, Column name: Reason_Quantity Error
# Used: False, Ranking: 86, Column name: Reason_Quantity Error v CPS
# Used: False, Ranking: 84, Column name: Reason_RO Tool - Billing option
# Used: False, Ranking: 82, Column name: Reason_Reason for Manual Order Error
# Used: False, Ranking: 80, Column name: Reason_Regional Program Manager - Adjustment Approval
# Used: False, Ranking: 78, Column name: Reason_Regional Program Manager - Exception Approval
# Used: False, Ranking: 76, Column name: Reason_Regional Program Manager - Exception Request
# Used: False, Ranking: 74, Column name: Reason_Regional Program Manager - Manual Order Approval
# Used: False, Ranking: 72, Column name: Reason_Regional Program Manager - Order related
# Used: False, Ranking: 70, Column name: Reason_Rework - Other
# Used: False, Ranking: 68, Column name: Reason_Rework - Rebill / Rework Incorrect
# Used: False, Ranking: 66, Column name: Reason_SAP - Account Holds
# Used: False, Ranking: 64, Column name: Reason_SAP - Other
# Used: False, Ranking: 62, Column name: Reason_SKU Description Error
# Used: False, Ranking: 60, Column name: Reason_SUB - Approval
# Used: False, Ranking: 56, Column name: Reason_SUB - Clarification Needed
# Used: False, Ranking: 54, Column name: Reason_SUB - Other
# Used: False, Ranking: 52, Column name: Reason_Signature
# Used: False, Ranking: 50, Column name: Reason_Signature Block Error
# Used: False, Ranking: 48, Column name: Reason_Standard Policy Error w/o Empowerment
# Used: False, Ranking: 44, Column name: Reason_Subscription Term Error
# Used: False, Ranking: 42, Column name: Reason_Subsidiary Invalid - Standard Policy Error w/o Empowerment
# Used: False, Ranking: 40, Column name: Reason_System Issue
# Used: False, Ranking: 38, Column name: Reason_Systems - BART issue
# Used: False, Ranking: 36, Column name: Reason_Systems - Chip Help - Other
# Used: False, Ranking: 34, Column name: Reason_Systems - Docusign - System issues
# Used: False, Ranking: 32, Column name: Reason_Systems - EDI/XML issue
# Used: False, Ranking: 24, Column name: Reason_Systems - EOLAS Issue
# Used: False, Ranking: 22, Column name: Reason_Systems - Explore ms - System issues
# Used: False, Ranking: 20, Column name: Reason_Systems - Global Sales Support - System issue
# Used: False, Ranking: 18, Column name: Reason_Systems - LIR - Awaiting data insertion into LIR
# Used: False, Ranking: 16, Column name: Reason_Systems - MIMOS - System issue
# Used: False, Ranking: 14, Column name: Reason_Systems - MOET Issue
# Used: False, Ranking: 12, Column name: Reason_Systems - MSL - Backend Correction
# Used: False, Ranking: 10, Column name: Reason_Systems - MSL - Contract cannot be activated
# Used: False, Ranking: 8, Column name: Reason_Systems - No Access to Tool
# Used: False, Ranking: 6, Column name: Reason_Systems - Papervision - System issues
# Used: False, Ranking: 4, Column name: Reason_Systems - Partner Quotes issue
# Used: False, Ranking: 2, Column name: Reason_Systems - SAP - Access issue/request
# Used: True, Ranking: 1, Column name: Reason_Systems - SAP - Change CP contact info in SAP
# Used: True, Ranking: 1, Column name: Reason_Systems - SAP - Reports request
# Used: True, Ranking: 1, Column name: Reason_Systems - System Issue
# Used: True, Ranking: 1, Column name: Reason_Systems - Unknown Query Response
# Used: True, Ranking: 1, Column name: Reason_Systems - VLCM Issue
# Used: True, Ranking: 1, Column name: Reason_Systems - VLSC Issue
# Used: True, Ranking: 1, Column name: Reason_Systems - eMSL Issue
# Used: True, Ranking: 1, Column name: Reason_Tax - Clarification Needed
# Used: True, Ranking: 1, Column name: Reason_Tax - Sales and Use Tax Issue
# Used: True, Ranking: 1, Column name: Reason_Tax - Tax Adjustment
# Used: True, Ranking: 1, Column name: Reason_Tax - Tax Credit Approval
# Used: True, Ranking: 1, Column name: Reason_Tax - Waiting for tax exempt form approval
# Used: True, Ranking: 1, Column name: Reason_Tier 2 - Tier 2 - Waiting for MSL backend correction
# Used: True, Ranking: 1, Column name: Reason_Trade - Trade Status Hold
# Used: True, Ranking: 1, Column name: Reason_Usage Country Error
# Used: True, Ranking: 1, Column name: Reason_Usage Date Error
# Used: True, Ranking: 1, Column name: Reason_VLCM - Agreement failed to activate
# Used: True, Ranking: 1, Column name: Reason_WWLP - Verify Fee Calculation
# Used: True, Ranking: 1, Column name: Reason_Waiting for Sub-Signature
# Used: True, Ranking: 1, Column name: Reason_Workbench
# Used: True, Ranking: 1, Column name: Reason_X - LIR - Awaiting data insertion into LIR
# Used: True, Ranking: 1, Column name: AssignedToGroup_CRMT
# Used: True, Ranking: 1, Column name: AssignedToGroup_Internal
# Used: True, Ranking: 1, Column name: AssignedToGroup_Microsoft IT
# Used: True, Ranking: 1, Column name: AssignedToGroup_Ops. Program Manager
# Used: True, Ranking: 1, Column name: AssignedToGroup_Submitter (Contact)
# Used: True, Ranking: 1, Column name: NewValueName_Ops In
# Used: True, Ranking: 1, Column name: NewValueName_Ops Out
# Used: True, Ranking: 1, Column name: NewValueName_Submission
# Used: True, Ranking: 1, Column name: NewValueName_Triage And Validation
# Used: True, Ranking: 1, Column name: OldValueName_Ops In
# Used: True, Ranking: 1, Column name: OldValueName_Ops Out
# Used: True, Ranking: 1, Column name: OldValueName_Submission
# Used: True, Ranking: 1, Column name: OldValueName_Triage And Validation
# Used: True, Ranking: 1, Column name: AmountinUSD
# Used: True, Ranking: 1, Column name: Complexity
# Used: True, Ranking: 1, Column name: CountryProcessed_asia
# Used: False, Ranking: 27, Column name: CountryProcessed_australia
# Used: True, Ranking: 1, Column name: CountryProcessed_europe
# Used: True, Ranking: 1, Column name: CountryProcessed_northamerica
# Used: False, Ranking: 29, Column name: CountryProcessed_other
# Used: True, Ranking: 1, Column name: CountryProcessed_southamerica
# Used: True, Ranking: 1, Column name: CountrySource_asia
# Used: False, Ranking: 31, Column name: CountrySource_australia
# Used: True, Ranking: 1, Column name: CountrySource_europe
# Used: True, Ranking: 1, Column name: CountrySource_northamerica
# Used: True, Ranking: 1, Column name: CountrySource_other
# Used: True, Ranking: 1, Column name: CountrySource_southamerica
# Used: True, Ranking: 1, Column name: IsGovernment
# Used: True, Ranking: 1, Column name: IsMagnumCase
# Used: True, Ranking: 1, Column name: IsSOXCase
# Used: True, Ranking: 1, Column name: IsSignature
# Used: False, Ranking: 100, Column name: Numberofreactivations
# Used: True, Ranking: 1, Column name: OLSRevenue
# Used: True, Ranking: 1, Column name: Priority
# Used: True, Ranking: 1, Column name: Queue_AOC
# Used: True, Ranking: 1, Column name: Queue_APOC
# Used: True, Ranking: 1, Column name: Queue_EOC
# Used: False, Ranking: 47, Column name: Queue_LOC
# Used: True, Ranking: 1, Column name: Queue_NAOC
# Used: True, Ranking: 1, Column name: ROCName_APOC
# Used: True, Ranking: 1, Column name: ROCName_EOC
# Used: True, Ranking: 1, Column name: Revenutype_Credit / Rebill
# Used: True, Ranking: 1, Column name: Revenutype_Current Revenue
# Used: True, Ranking: 1, Column name: Revenutype_Disputed Revenue
# Used: True, Ranking: 1, Column name: Revenutype_Future Billing
# Used: True, Ranking: 1, Column name: Revenutype_Future OTRRR with OLS
# Used: True, Ranking: 1, Column name: Revenutype_Future OTRRR without OLS
# Used: True, Ranking: 1, Column name: Revenutype_New Work Sold
# Used: True, Ranking: 1, Column name: Revenutype_Non-revenue
# Used: True, Ranking: 1, Column name: Revenutype_Revenue Impacting Case / Pending Revenue
# Used: True, Ranking: 1, Column name: Revenutype_Revenue Unknown
# Used: True, Ranking: 1, Column name: SalesLocation_asia
# Used: True, Ranking: 1, Column name: SalesLocation_australia
# Used: True, Ranking: 1, Column name: SalesLocation_europe
# Used: True, Ranking: 1, Column name: SalesLocation_northamerica
# Used: True, Ranking: 1, Column name: SalesLocation_southamerica
# Used: True, Ranking: 1, Column name: Source_Fax
# Used: True, Ranking: 1, Column name: Source_Hard Copy
# Used: True, Ranking: 1, Column name: Source_Manual
# Used: True, Ranking: 1, Column name: Source_Soft Copy
# Used: True, Ranking: 1, Column name: Source_Web
# Used: False, Ranking: 102, Column name: Source_eAgreement (Ele)
# Used: False, Ranking: 104, Column name: Source_eAgreement (Phy)
# Used: True, Ranking: 1, Column name: StageName_Ops In
# Used: True, Ranking: 1, Column name: StageName_Ops Out
# Used: True, Ranking: 1, Column name: StageName_Submission
# Used: False, Ranking: 144, Column name: StageName_Triage And Validation
# Used: False, Ranking: 105, Column name: StatusReason_Information Provided
# Used: True, Ranking: 1, Column name: StatusReason_Problem Solved
# Used: True, Ranking: 1, Column name: SubReason_Basic Enterprise Commitment
# Used: True, Ranking: 1, Column name: SubReason_Electronic Order Pend / Reject
# Used: True, Ranking: 1, Column name: SubReason_Future Pricing Only CPS
# Used: True, Ranking: 1, Column name: SubReason_Manual Order Entry
# Used: True, Ranking: 1, Column name: SubReason_Meteaop
# Used: False, Ranking: 59, Column name: SubReason_P&H Electronic Order
# Used: True, Ranking: 1, Column name: SubReason_Tax Exemption Order
# Used: True, Ranking: 1, Column name: SubReason_True Up
# Used: True, Ranking: 1, Column name: SubReason_Zero Usage Order
# Used: False, Ranking: 156, Column name: sourcesystem_Aplquest
# Used: False, Ranking: 158, Column name: sourcesystem_CLT
# Used: False, Ranking: 160, Column name: sourcesystem_Current Revenue
# Used: False, Ranking: 162, Column name: sourcesystem_Moritz Jürgensen
# Used: False, Ranking: 164, Column name: sourcesystem_NEMEC
# Used: False, Ranking: 166, Column name: sourcesystem_NMEC
# Used: False, Ranking: 168, Column name: sourcesystem_Web
# Used: False, Ranking: 170, Column name: sourcesystem_clt
# Used: False, Ranking: 172, Column name: sourcesystem_web
#
# train score (k = half features and step = 1):  0.991741710103
# test score: (k = half features and step = 1):  -4.11291971115
