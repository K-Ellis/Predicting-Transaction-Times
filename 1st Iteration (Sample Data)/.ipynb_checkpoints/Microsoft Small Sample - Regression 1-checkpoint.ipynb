# %%
import pandas as pd
from sklearn import cross_validation, svm
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression, ElasticNet, Lasso, Ridge
import numpy as np
import math
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# dataset = "SampleData3_moreInstances.csv"
dataset = "SampleData4.xlsx"
# dataset = "SampleData2.csv"
# df = pd.read_csv(dataset,encoding='latin-1')
df = pd.read_excel(dataset)#,encoding='latin-1')
# df.dropna(inplace=True)

y = pd.DataFrame()
# y_label = "time_to_complete"
y_label = "Days"
y = df.pop(y_label)

x = pd.DataFrame()
for col in list(df):
    dummies = pd.get_dummies(df[col]).iloc[:, 1:]
    x = pd.concat([x, dummies], axis = 1)

x_train, x_test, y_train, y_test = cross_validation.train_test_split(x, y, test_size = 0.2)

y_test_list = [x for x in y_test]


regr = LinearRegression()

regr.fit(x_train, y_train)
accuracy = regr.score(x_test, y_test)
print("accuracy/ Variance Score = %s" % (accuracy)) # directional accuracy
print("Mean squared error: %.2f"% np.mean((regr.predict(x_test) - y_test) ** 2))
print("function = %s"%(fn))
print()
predictions = regr.predict(x_test)
plt.scatter(y_test, predictions) # , label = "prediction")
#     plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r', lw=2)
plt.xlabel("Actual")
plt.ylabel("Prediction")
plt.title("Linear Regression")
plt.ylim(-1,13)
plt.xlim(-1,18)
plt.show()
    
regr = RandomForestRegressor(n_estimators=100)

regr.fit(x_train, y_train)
accuracy = regr.score(x_test, y_test)
print("accuracy/ Variance Score = %s" % (accuracy)) # directional accuracy
print("Mean squared error: %.2f"% np.mean((regr.predict(x_test) - y_test) ** 2))
print("function = %s"%(fn))
print()
predictions = regr.predict(x_test)
plt.scatter(y_test, predictions) # , label = "prediction")
#     plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r', lw=2)
plt.xlabel("Actual")
plt.ylabel("Prediction")
plt.title("Random Forest Regressor")
plt.ylim(-1,13)
plt.xlim(-1,18)
plt.show()
# Out:
# accuracy/ Variance Score = -1.09245156818e+24
# Mean squared error: 12727548849421149246849024.00
# function = LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# accuracy/ Variance Score = 0.140114809876
# Mean squared error: 10.02
# function = LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
# dataset = "SampleData3_moreInstances.csv"
# dataset = "SampleData2.csv"
dataset = "SampleData4.xlsx"
# df = pd.read_csv(dataset,encoding='latin-1')
df = pd.read_excel(dataset)
# df.dropna(inplace=True)

y = pd.DataFrame()
# y_label = "time_to_complete"
y_label = "Days"
y = df.pop(y_label)

x = pd.DataFrame()
for col in list(df):
    dummies = pd.get_dummies(df[col]).iloc[:, 1:]
    x = pd.concat([x, dummies], axis = 1)

x_train, x_test, y_train, y_test = cross_validation.train_test_split(x, y, test_size = 0.2)

y_test_list = [x for x in y_test]

fns = [LinearRegression(), svm.SVR(), svm.SVR(kernel = "poly"), RandomForestRegressor(n_estimators=100), 
       ElasticNet(),Ridge(), Lasso()]
for fn in fns:
    regr = fn
    regr.fit(x_train, y_train)
    accuracy = regr.score(x_test, y_test)
    print("accuracy/ Variance Score = %s" % (accuracy)) # directional accuracy
    print("Mean squared error: %.2f"% np.mean((regr.predict(x_test) - y_test) ** 2))
    print("function = %s"%(fn))
    print()
    predictions = regr.predict(x_test)
    
    plt.plot(predictions, label = "prediction")
    plt.plot(y_test_list, color = "red", label = "actual")
    plt.legend(loc = 1)
    plt.xlim(0,73)
    plt.xlabel("ticks")
    plt.ylabel("time to complete")
    plt.show()
    
    plt.scatter(y_test, predictions) # , label = "prediction")
#     plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r', lw=2)
    plt.xlabel("Actual")
    plt.ylabel("Prediction")
    plt.show()
    
    print("--------------------------------------")
# Out:
# accuracy/ Variance Score = -2.2963487084e+22
# Mean squared error: 286213892558445697040384.00
# function = LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# --------------------------------------
# accuracy/ Variance Score = -0.011803671737
# Mean squared error: 12.61
# function = SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)
# --------------------------------------
# accuracy/ Variance Score = -0.102655816389
# Mean squared error: 13.74
# function = SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='poly', max_iter=-1, shrinking=True, tol=0.001, verbose=False)
# --------------------------------------
# accuracy/ Variance Score = 0.0957685466711
# Mean squared error: 11.27
# function = RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
# ...

# %%
# plt.plot(x_test, predictions)
# plt.show()

# %%
"""dataset = "SampleData3_moreInstances.csv"
# dataset = "SampleData2.csv"
df = pd.read_csv(dataset,encoding='latin-1')
df.dropna(inplace=True)

y = pd.DataFrame()
y_label = "time_to_complete"
# y_label = "Days"
y = df.pop(y_label)

x = pd.DataFrame()
for col in list(df):
    dummies = pd.get_dummies(df[col]).iloc[:, 1:]
    x = pd.concat([x, dummies], axis = 1)

x_train, x_test, y_train, y_test = cross_validation.train_test_split(x, y, test_size = 0.2)

y_test_list = [x for x in y_test]

fns = [LinearRegression(), svm.SVR(), svm.SVR(kernel = "poly"), RandomForestRegressor(n_estimators=100), 
       ElasticNet(),Ridge(), Lasso()]
for fn in fns:
    regr = fn
    regr.fit(x_train, y_train)
    accuracy = regr.score(x_test, y_test)
    print("accuracy/ Variance Score = %s" % (accuracy)) # directional accuracy
    print("Mean squared error: %.2f"% np.mean((regr.predict(x_test) - y_test) ** 2))
    print("function = %s"%(fn))
    print()
    predictions = regr.predict(x_test)
    plt.plot(predictions, label = "prediction")
   
    plt.plot(y_test_list, color = "red", label = "actual")

    plt.x_label = "ticks"
    plt.y_label = "days to complete"
    plt.legend(loc = 1)
    plt.xlim(0,73)
    plt.show()
    print("--------------------------------------")"""
